# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\shifa\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shifa\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shifa\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shifa\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shifa\anaconda3\lib\site-packages (from requests) (2025.11.12)

# %%
import requests

# %%
#api-request practise
URL = "https://stephen-king-api.onrender.com/api/books"
res = requests.get(URL)

# %%
res
# Out:
# <Response [200]>

# %%
json_data = res.json()

# %%
import pandas as pd
df = pd.json_normalize(json_data["data"])
df[["id", "Title", "ISBN"]]
# Out:
#     id          Title               ISBN
# 0    1         Carrie  978-0-385-08695-0
# 1    2    Salem's Lot  978-0-385-00751-1
# 2    3    The Shining  978-0-385-12167-5
# 3    4           Rage  978-0-451-07645-8
# 4    5      The Stand  978-0-385-12168-2
# ..  ..            ...                ...
# 58  59   The Outsider  978-1-50118-098-9
# 59  60      Elevation  978-1-98210-231-9
# 60  61  The Institute  978-1-98211-056-7
# 61  62          Later  978-1-78909-649-1
# 62  63  Billy Summers  978-1-982-17361-6
#
# [63 rows x 3 columns]

# %%
#api-request mini-activity
URL = "https://whiskyhunter.net/api/?format=openapi"
resp = requests.get(URL)
resp
# Out:
# <Response [200]>

# %%
json_data = resp.json()

# %%
json_data
# Out:
# {'swagger': '2.0',
#  'info': {'title': 'Whisky Hunter API',
#   'description': 'All trading volumes and winning bids are stated in <strong>£ (GBP)</strong>. Regardless of the base currency of the auction. \nThe volume calculation for auctions or distilleries includes only the lots actually sold (excluding those that have not reached the reserve price)',
#   'termsOfService': '/privacy-policy/',
#   'version': 'v1'},
#  'host': 'whiskyhunter.net',
#  'schemes': ['https'],
#  'basePath': '/api',
#  'consumes': ['application/json'],
#  'produces': ['application/json'],
#  'securityDefinitions': {'Basic': {'type': 'basic'}},
#  'security': [{'Basic': []}],
#  'paths': {'/auction_data/{slug}/': {'get': {'operationId': 'auction_data_read',
#     'description': 'List only aggregated data for online auction {slug}. Example: /api/auction_data/catawiki/',
#     'parameters': [],
#     'responses': {'200': {'description': ''}},
#     'tags': ['auction_data']},
#    'parameters': [{'name': 'slug',
#      'in': 'path',
#      'required': True,
#      'type': 'string'}]},
#   '/auctions_data/': {'get': {'operationId': 'auctions_data_list',
#     'description': 'List all online auctions aggregated data.',
#     'parameters': [],
#     'responses': {'200': {'description': ''}},
#     'tags': ['auctions_data']},
#    'parameters': []},
#   '/auctions_info': {'get': {'operationId': 'auctions_info_list',
#     'description': 'List all online auctions main information.',
#     'parameters': [],
#     'responses': {'200': {'description': ''}},
#     'tags': ['auctions_info']},
#    'parameters': []},
#   '/distilleries_info/': {'get': {'operationId': 'distilleries_info_list',
#     'description': 'List all distilleries main information.',
#     'parameters': [],
#     'responses': {'200': {'description': ''}},
#     'tags': ['distilleries_info']},
#    'parameters': []},
#   '/distillery_data/{slug}/': {'get': {'operationId': 'distillery_data_read',
#     'description': 'List data for distillery {slug}. Example: /api/distillery_data/ardbeg/',
#     'parameters': [],
#     'responses': {'200': {'description': ''}},
#     'tags': ['distillery_data']},
#    'parameters': [{'name': 'slug',
#      'in': 'path',
#      'required': True,
#      'type': 'string'}]}},
#  'definitions': {}}

# %%
df = pd.json_normalize(json_data)
df
# Out:
#   swagger              host  schemes basePath            consumes  \
# 0     2.0  whiskyhunter.net  [https]     /api  [application/json]
#
#              produces         security         info.title  \
# 0  [application/json]  [{'Basic': []}]  Whisky Hunter API
#
#                                     info.description info.termsOfService  ...  \
# 0  All trading volumes and winning bids are state...    /privacy-policy/  ...
#
#   paths./distilleries_info/.get.parameters  \
# 0                                       []
#
#   paths./distilleries_info/.get.responses.200.description  \
# 0
#
#   paths./distilleries_info/.get.tags paths./distilleries_info/.parameters  \
# 0                [distilleries_info]                                   []
#
#   paths./distillery_data/{slug}/.get.operationId  \
# 0                           distillery_data_read
#
#       paths./distillery_data/{slug}/.get.description  \
# 0  List data for distillery {slug}. Example: /api...
#
#   paths./distillery_data/{slug}/.get.parameters  \
# 0                                            []
#
#   paths./distillery_data/{slug}/.get.responses.200.description  \
# 0
#
#   paths./distillery_data/{slug}/.get.tags  \
# 0                       [distillery_data]
#
#            paths./distillery_data/{slug}/.parameters
# 0  [{'name': 'slug', 'in': 'path', 'required': Tr...
#
# [1 rows x 42 columns]

# %%
#web-scraping of a simple website
import requests
URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)
res
# Out:
# <Response [200]>

# %%
if res.status_code == 200 :
    print(res.headers)

with open ("scraped_data/data1.html", "w", encoding="utf-8") as f:
    f.write(res.text)
# Out:
# {'Date': 'Sat, 07 Mar 2026 02:52:52 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=o6OsfF7AkSAgFkdc1NSFr3q35Ctzh9H8R3gRni%2BGj5k%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1772851972"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=o6OsfF7AkSAgFkdc1NSFr3q35Ctzh9H8R3gRni%2BGj5k%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1772851972"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': '9d864e76fbdb9fbc-SIN', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\shifa\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shifa\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\shifa\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)

# %%
from bs4 import BeautifulSoup

with open("scraped_data/data1.html", "r") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "lxml")

# %%
all_h3 = soup.find_all("h3")
all_countries = []
for h3 in all_h3:
    names = h3.get_text(strip=True)
    # print(h3.find_parent("div")["class"])
    population = h3.find_next("div").select("span.country-population")[0].get_text(strip=True)
    all_countries.append([names, population])

# %%
import pandas as pd
df = pd.DataFrame(all_countries, columns = ["Name", "Population"])

# %%
df.to_csv("cleaned_data/data.csv", index = False)

# %%
#web-scraping activity

URL = "http://quotes.toscrape.com/"
res = requests.get(URL)
res
# Out:
# <Response [200]>

# %%
with open("scraped_data/data2.html", "w", encoding = "utf-8") as f:
    f.write(res.text)

# %%
with open("scraped_data/data2.html", "r", encoding="utf-8") as f:
    html_content2 = f.read()

soup2 = BeautifulSoup(html_content2, "lxml")
