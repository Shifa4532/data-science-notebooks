# %%
import pandas as pd

# %%
df_csv = pd.read_csv("IRIS.csv")

# %%
df_csv.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df_csv.shape
# Out:
# (150, 5)

# %%
df_csv.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df_csv.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df_csv2 = df_csv
df_csv2.groupby("species")["sepal_length"].mean()
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: sepal_length, dtype: float64

# %%
df_csv2.groupby("species")["sepal_length"].std()
# Out:
# species
# Iris-setosa        0.352490
# Iris-versicolor    0.516171
# Iris-virginica     0.635880
# Name: sepal_length, dtype: float64

# %%
df_csv2.groupby("species")["sepal_length"].min()
# Out:
# species
# Iris-setosa        4.3
# Iris-versicolor    4.9
# Iris-virginica     4.9
# Name: sepal_length, dtype: float64

# %%
df_csv2.groupby("species")["sepal_length"].max()
# Out:
# species
# Iris-setosa        5.8
# Iris-versicolor    7.0
# Iris-virginica     7.9
# Name: sepal_length, dtype: float64
