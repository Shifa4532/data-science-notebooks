# %%
import pandas as pd

# %%
df_csv = pd.read_csv("iris-dataset.csv")

# %%
df_csv.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df_csv.shape
# Out:
# (150, 5)

# %%
df_csv.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df_csv.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df_csv2 = df_csv
df_csv2.groupby("species")["sepal_length"].agg(["mean", "max", "std", "min"])
# Out:
#                   mean  max       std  min
# species
# Iris-setosa      5.006  5.8  0.352490  4.3
# Iris-versicolor  5.936  7.0  0.516171  4.9
# Iris-virginica   6.588  7.9  0.635880  4.9

# %%
df_csv.query("petal_length > 4.5 and species == 'Iris-virginica'")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 108           6.7          2.5           5.8          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# ...

# %%
df_csv2.groupby("species").agg(
    avg_sepal_width = ("sepal_width", "mean"),
    max_petal_width = ("petal_width" , "max"),
    std_sepal_width = ("sepal_width", "std")
)
# Out:
#                  avg_sepal_width  max_petal_width  std_sepal_width
# species
# Iris-setosa                3.418              0.6         0.381024
# Iris-versicolor            2.770              1.8         0.313798
# Iris-virginica             2.974              2.5         0.322497

# %%
df_csv3 = df_csv.assign(petal_ratio = df_csv["petal_length"] / df_csv["petal_width"])
df_csv3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      petal_ratio
# 0       7.000000
# 1       7.000000
# 2       6.500000
# ...

# %%
df_csv3.groupby("species")["petal_ratio"].mean()
# Out:
# species
# Iris-setosa        7.078000
# Iris-versicolor    3.242837
# Iris-virginica     2.780662
# Name: petal_ratio, dtype: float64
